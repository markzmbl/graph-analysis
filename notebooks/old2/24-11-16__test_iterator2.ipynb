# %%
from utils import GraphEdgeIterator

# %%
for s, d, t in GraphEdgeIterator():
    pass
    # print(s, d, t)
# Out:
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# swapped buffer
# ...
